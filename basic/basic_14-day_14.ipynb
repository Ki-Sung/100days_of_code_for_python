# %% [markdown]
# ### Higher-Lower Game
#     Web 게임 Higher-Lower Game 참고
# 1. classic 버튼 클릭 - classic 버전은 두 검색어를 비교하는 게임
# 2. 두 가지 검색어를 랜덤으로 제시
# 3. 두 개 검색어 선택
#     - 만약 검색량이 많은 검색어를 선택했다면, 다음 키워드로 넘어감과 동시에 1점 획득
#     - 만약 검색량이 적은 검색어를 선택했다면, 게임 종료
# 4. 게임이 종료되면 최종적으로 맞춘 점수 보여주기, 그리고 게임 다시시작 여부 묻기

# %% [markdown]
# ### 우리가 해야할 final project Higer-Lower Game 방법
# - 게임 목적 - 누구의 인스타 팔로워가 더 많을까 맞추기
# 1. 로고 출력
# 2. 비교 상대 랜덤으로 출력
#     - Compare A: name, description, country vs Against B: name, description, country (vs는 로고 사용)
#     - who has more followers? Type 'A' or 'B': 입력 문구 출력
# 3. 만약 팔로워수가 많은 사람을 골랐다면
#     - You're right! Current score: 가 1씩 증가
#     - 만약 B를 맞췄다면가 B를 A로 올림
#     - 그리고 다시 랜덤으로 비교 상대 출력
# 4. 만약 팔로워수가 적은 사람을 골랐다면
#     - Sorry, that's wrong. Final score: 출력 후 게임 종료

# %% [markdown]
# ### 코드 작성시 우리가 해야할 사항
# 1. 문제를 작게 나누기 - 작은 문제 하나씩 해결하면서 작업
# 2. to-do list 작성
# 3. 2번 to-do를 바탕으로 주석으로 입력후 코드를 나눠서 입력
# 4. 코드를 작성하고 -> 코드를 실행시키고 -> 에러 코드 고치는 작업 반복

# %% [markdown]
# ### My solution

# %%
import random
from higher_lower import art
from higher_lower import game_data

# 1. 로고 출력 
print(art.logo)              # 시작 로고 

# 2. 팔로우 데이터 불러오기 
data = game_data.data

game_over = False
score = 0
while not game_over:
    # 3. 초반에 랜덤하게 두 대결 상대를 출력 
    compare = random.choice(data)
    print("Compare A: " + compare['name'] + ", " + compare['description'] + ", " + "from " + compare['country'])
    print(art.vs)                # vs 로고 
    against = random.choice(data)
    print("Against B: " + against['name'] + ", " + against['description'] + ", " + "from " + against['country'])
    
    # 4. 선택할 수 있게 input 할 사항 넣기
    choice = input("Who has more followers? Type 'A' or 'B': ")
    if choice == 'A':
        choice_result = compare['follower_count']
    else:
        choice_result = against['follower_count']
        
    if choice_result > compare['follower_count']:
        score += 1
        print(f"you got it Current score: {score}")
    elif choice_result > against['follower_count']:
        score += 1
        print(f"you got it Current score: {score}")
    else:
        print(f"Sorry, that's wrong. Final score:{score}")
        game_over = True
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Ariana Grande, Musician and actress, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Justin Timberlake, Musician and actor, from United States
# Who has more followers? Type 'A' or 'B': A
# you got it Current score: 1
# Compare A: Maluma, Musician, from Colombia
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Billie Eilish, Musician, from United States
# Who has more followers? Type 'A' or 'B': B
# you got it Current score: 2
# Compare A: UEFA Champions League, Club football competition, from Europe
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Chris Brown, Musician, from United States
# Who has more followers? Type 'A' or 'B': B
# you got it Current score: 3
# Compare A: Katy Perry, Musician, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Demi Lovato, Musician and actress, from United States
# Who has more followers? Type 'A' or 'B': A
# you got it Current score: 4
# Compare A: NASA, Space agency, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Victoria's Secret, Lingerie brand, from United States
# Who has more followers? Type 'A' or 'B': A
# Sorry, that's wrong. Final score:4

# %% [markdown]
# ### Teacher solution
# - Follow the process
#     1. Display art.
#     2. Generate a random account from the game data.
#     3. Format the account data into printable format.
#     4. Ask user for a guess.
#     5. Check if user is correct.
#         - Get follower count of each account.
#         - Use if statement to check if user is correct.
#     6. Give user feedback on their guess.
#     7. Score keeping
#     8. Make the game repeatable.
#     9. Making account at position B become the next account at position A.
#     10. Clear the screen between rounds.

# %%
from higher_lower import art
# 1. Display art
print(art.logo)
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/

# %%
import random
from higher_lower import game_data

# 2. Generate a random account from the game data.
account_a = random.choice(game_data.data)
account_b = random.choice(game_data.data)
if account_a == account_b:
    account_b = random.choice(game_data.data)

# %%
# 3. Format the account data into printable format.
account_name = account_a["name"]
account_descr = account_a["description"]
account_country = account_a["country"]
print(f"{account_name}, a {account_descr}, from {account_country}")

account_name = account_b["name"]
account_descr = account_b["description"]
account_country = account_b["country"]
print(f"{account_name}, b {account_descr}, from {account_country}")

# Create to Format the account data into printable format.

def format_data(account):
    """ Format the account data and return the printable format."""
    account_name = account["name"]
    account_descr = account["description"]
    account_country = account["country"]
    return f"{account_name}, a {account_descr}, from {account_country}"

# %%
# 4. Ask user for a guess.
guess = input("Who has more followers? Type 'A' or 'B': ").lower()

# %%
# 5. Check if user is correct.
## Get follower count of each account.
a_follower_count = account_a["follower_count"]
b_follower_count = account_b["follower_count"]

## Use if statement to check if user is correct
def check_answer(guess, a_followers, b_followers):
    """Take the user guess and follower counts and returns if they got it right."""
    if a_followers > b_followers:
        return guess == "a"
    else:
        return guess == "b"

is_correct = check_answer(guess, a_follower_count, b_follower_count)

# %%
# 6. Give user feedback on their guess and 
# 7. Score keeping

score = 0

if is_correct:
    score += 1
    print(f"You're right! Current score: {score}.")
else:
    print(f"Sorry, that's wrong. Final score: {score}.")

# %%
# 8. Make the game repeatable.
game_should_countinue = True

while game_should_countinue:
    account_a = random.choice(game_data.data)
    account_b = random.choice(game_data.data)
    if account_a == account_b:
        account_b = random.choice(game_data.data)

    print(f"Compare A: {format_data(account_a)}")
    print(art.vs)
    print(f"Against B: {format_data(account_b)}")

    guess = input("Who has more followers? Type 'A' or 'B': ").lower()

    a_follower_count = account_a["follower_count"]
    b_follower_count = account_b["follower_count"]
    is_correct = check_answer(guess, a_follower_count, b_follower_count)

    if is_correct:
        score += 1
        print(f"You're right! Current score: {score}.")
    else:
        game_should_countinue = False
        print(f"Sorry, that's wrong. Final score: {score}.")

# %%
# 9. Making account at position B become the next account at position A
account_b = random.choice(game_data.data)
while game_should_countinue:
    
    account_a = account_b
    account_b = random.choice(game_data.data)
    ...

# %%
# 10. Clear the screen between rounds.
import os
os.system('clear')

# %%
# Final code
import os
import random
from higher_lower import art
from higher_lower import game_data

# Format the account data into printable format.
def format_data(account):
    """Format the account data and return the printable format."""
    account_name = account["name"]
    account_descr = account["description"]
    account_country = account["country"]
    return f"{account_name}, a {account_descr}, from {account_country}"

## Use if statement to check if user is correct
def check_answer(guess, a_followers, b_followers):
    """Take the user guess and follower counts and returns if they got it right."""
    if a_followers > b_followers:
        return guess == "a"
    else:
        return guess == "b"

# Display art
print(art.logo)

score = 0
game_should_countinue = True
account_b = random.choice(game_data.data)

# Make the game repeatable.
while game_should_countinue:
    # Generate a random account from the game data.
    
    # Making account at position B become the next account at position A
    account_a = account_b
    account_b = random.choice(game_data.data)
    
    if account_a == account_b:
        account_b = random.choice(game_data.data)

    print(f"Compare A: {format_data(account_a)}")
    print(art.vs)
    print(f"Against B: {format_data(account_b)}")

    # Ask user for a guess.
    guess = input("Who has more followers? Type 'A' or 'B': ").lower()

    # Check if user is correct.
    ## Get follower count of each account.
    a_follower_count = account_a["follower_count"]
    b_follower_count = account_b["follower_count"]
    is_correct = check_answer(guess, a_follower_count, b_follower_count)
    
    # Clear the screen between rounds.
    os.system("clear")
    print(art.logo)
    
    # Give user feedback on their guess.
    # Score keeping
    if is_correct:
        score += 1
        print(f"You're right! Current score: {score}.")
    else:
        game_should_countinue = False
        print(f"Sorry, that's wrong. Final score: {score}.")
# Out:
#     __  ___       __
#    / / / (_)___ _/ /_  ___  _____
#   / /_/ / / __ `/ __ \/ _ \/ ___/
#  / __  / / /_/ / / / /  __/ /
# /_/ ///_/\__, /_/ /_/\___/_/
#    / /  /____/_      _____  _____
#   / /   / __ \ | /| / / _ \/ ___/
#  / /___/ /_/ / |/ |/ /  __/ /
# /_____/\____/|__/|__/\___/_/
#
# Compare A: Kendall Jenner, a Reality TV personality and Model, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Justin Bieber, a Musician, from Canada
# Who has more followers? Type 'A' or 'B': B
# You're right! Current score: 1.
# Compare A: Justin Bieber, a Musician, from Canada
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Zendaya, a Actress and musician, from United States
# Who has more followers? Type 'A' or 'B': A
# You're right! Current score: 2.
# Compare A: Zendaya, a Actress and musician, from United States
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: 9GAG, a Social media platform, from China
# Who has more followers? Type 'A' or 'B': A
# You're right! Current score: 3.
# Compare A: 9GAG, a Social media platform, from China
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Camila Cabello, a Musician, from Cuba
# Who has more followers? Type 'A' or 'B': A
# You're right! Current score: 4.
# Compare A: Camila Cabello, a Musician, from Cuba
#
#  _    __
# | |  / /____
# | | / / ___/
# | |/ (__  )
# |___/____(_)
#
# Against B: Vin Diesel, a Actor, from United States
# Who has more followers? Type 'A' or 'B': A
# Sorry, that's wrong. Final score: 4.
